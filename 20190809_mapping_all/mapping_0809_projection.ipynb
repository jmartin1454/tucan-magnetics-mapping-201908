# %% [markdown]
# ### Projection of the mapping data to 2D plots

# %%
import pandas as pd
import numpy as np
# %matplotlib notebook
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib.ticker import FormatStrFormatter
import numpy as np

# %%
df1 = pd.read_csv('Mapping_0809_RUN1.csv')
df2 = pd.read_csv('Mapping_0809_RUN2.csv')
df3 = pd.read_csv('Mapping_0809_RUN3.csv')
df4 = pd.read_csv('Mapping_0809_RUN4.csv')

df_all0 = df1.append(df2)
df_all1  = df_all0.append(df3)
df_all  = df_all1.append(df4)

# %%
u_4 =  df4.u.unique()
w_4 = df4.w.unique()
v_4 = df4.v.unique()
print u_4
print v_4
print w_4
# Out:
# [ 12.05  -7.95 -27.95 -67.95]
# [ 42.37  82.37 122.37 162.37 202.37]
# [-32.75   7.25  47.25  87.25 127.25 167.25 327.25 207.25 247.25 287.25]

# %%
fig0, ax0 = plt.subplots(2,3, figsize=(11,6))

for i in range(2):
    for j in range(len(w_4)):
            ax0[0,0].plot(df4[(df4.u==u_4[i])& (df4.w==w_4[j])].v, df4[(df4.u==u_4[i])& (df4.w==w_4[j])].B_u, 
                          '.-', lw=0.8, label='u=%.2f,w=%.2f'%(u_4[i], w_4[j]))
            ax0[0,1].plot(df4[(df4.u==u_4[i])& (df4.w==w_4[j])].v, df4[(df4.u==u_4[i])& (df4.w==w_4[j])].B_v, 
                           '.-', lw=0.8, label='u=%.2f,w=%.2f'%(u_4[i], w_4[j]))
            ax0[0,2].plot(df4[(df4.u==u_4[i])& (df4.w==w_4[j])].v, df4[(df4.u==u_4[i])& (df4.w==w_4[j])].B_w, 
                           '.-', lw=0.8, label='u=%.2f,w=%.2f'%(u_4[i], w_4[j]))

for i in range(2,4):
    for j in range(len(w_4)):
            ax0[1,0].plot(df4[(df4.u==u_4[i])& (df4.w==w_4[j])].v, df4[(df4.u==u_4[i])& (df4.w==w_4[j])].B_u, 
                          '.-', lw=0.8, label='u=%.2f,w=%.2f'%(u_4[i], w_4[j]))
            ax0[1,1].plot(df4[(df4.u==u_4[i])& (df4.w==w_4[j])].v, df4[(df4.u==u_4[i])& (df4.w==w_4[j])].B_v, 
                           '.-', lw=0.8, label='u=%.2f,w=%.2f'%(u_4[i], w_4[j]))
            ax0[1,2].plot(df4[(df4.u==u_4[i])& (df4.w==w_4[j])].v, df4[(df4.u==u_4[i])& (df4.w==w_4[j])].B_w, 
                           '.-', lw=0.8, label='u=%.2f,w=%.2f'%(u_4[i], w_4[j]))


for i in [0,1]:
    for j in [0,1,2]:
        ax0[i,j].legend(fontsize=3.5, loc='upper right')
        ax0[i,0].set_ylabel('$\mathsf{B_u}\,(G)$')
        ax0[i,1].set_ylabel('$\mathsf{B_v}\,(G)$')
        ax0[i,2].set_ylabel('$\mathsf{B_w}\,(G)$')
        ax0[i,j].set_xlabel('$\mathsf{v}\,(cm)$')
fig0.tight_layout(pad=1, h_pad=1,rect=[0,0,0.9,0.9])
fig0.savefig('plots_gradients/gradient_v')
# Out:
# <img src="data:image/png;base64,..." width="1100">

# %%
fig1, ax1 = plt.subplots(2,3, figsize=(11,6))


for i in range(2):
    for j in range(len(w_4)):
            ax1[0,0].plot(df4[(df4.v==v_4[i])& (df4.w==w_4[j])].u, df4[(df4.v==v_4[i])& (df4.w==w_4[j])].B_u, 
                          '.-', lw=0.8, label='v=%.2f,w=%.2f'%(v_4[i], w_4[j]))
            ax1[0,1].plot(df4[(df4.v==v_4[i])& (df4.w==w_4[j])].u, df4[(df4.v==v_4[i])& (df4.w==w_4[j])].B_v, 
                           '.-', lw=0.8, label='v=%.2f,w=%.2f'%(v_4[i], w_4[j]))
            ax1[0,2].plot(df4[(df4.v==v_4[i])& (df4.w==w_4[j])].u, df4[(df4.v==v_4[i])& (df4.w==w_4[j])].B_w, 
                           '.-', lw=0.8, label='v=%.2f,w=%.2f'%(v_4[i], w_4[j]))

for i in range(3,5):
    for j in range(len(w_4)):
            ax1[1,0].plot(df4[(df4.v==v_4[i])& (df4.w==w_4[j])].u, df4[(df4.v==v_4[i])& (df4.w==w_4[j])].B_u, 
                          '.-', lw=0.8, label='v=%.2f,w=%.2f'%(v_4[i], w_4[j]))
            ax1[1,1].plot(df4[(df4.v==v_4[i])& (df4.w==w_4[j])].u, df4[(df4.v==v_4[i])& (df4.w==w_4[j])].B_v, 
                           '.-', lw=0.8, label='v=%.2f,w=%.2f'%(v_4[i], w_4[j]))
            ax1[1,2].plot(df4[(df4.v==v_4[i])& (df4.w==w_4[j])].u, df4[(df4.v==v_4[i])& (df4.w==w_4[j])].B_w, 
                           '.-', lw=0.8, label='v=%.2f,w=%.2f'%(v_4[i], w_4[j]))


for i in [0,1]:
    for j in [0,1,2]:
        ax1[i,j].legend(fontsize=4, loc='upper left')
        ax1[i,0].set_ylabel('$\mathsf{B_u}\,(G)$')
        ax1[i,1].set_ylabel('$\mathsf{B_v}\,(G)$')
        ax1[i,2].set_ylabel('$\mathsf{B_w}\,(G)$')
        ax1[i,j].set_xlabel('$\mathsf{u}\,(cm)$')
fig1.tight_layout(pad=1, h_pad=1,rect=[0,0,0.9,0.9])
fig1.savefig('plots_gradients/gradient_u')
# Out:
# <img src="data:image/png;base64,..." width="1100">

# %%
fig2, ax2 = plt.subplots(2,3, figsize=(11,6))

for i in range(2):
    for j in range(len(v_4)):
            ax2[0,0].plot(df4[(df4.u==u_4[i])& (df4.v==v_4[j])].w, df4[(df4.u==u_4[i])& (df4.v==v_4[j])].B_u, 
                          '.-', lw=0.8, label='u=%.2f,v=%.2f'%(u_4[i], v_4[j]))
            ax2[0,1].plot(df4[(df4.u==u_4[i])& (df4.v==v_4[j])].w, df4[(df4.u==u_4[i])& (df4.v==v_4[j])].B_v, 
                           '.-', lw=0.8, label='u=%.2f,v=%.2f'%(u_4[i], v_4[j]))
            ax2[0,2].plot(df4[(df4.u==u_4[i])& (df4.v==v_4[j])].w, df4[(df4.u==u_4[i])& (df4.v==v_4[j])].B_w, 
                           '.-', lw=0.8, label='u=%.2f,v=%.2f'%(u_4[i], v_4[j]))

for i in range(2,4):
    for j in range(len(v_4)):
            ax2[1,0].plot(df4[(df4.u==u_4[i])& (df4.v==v_4[j])].w, df4[(df4.u==u_4[i])& (df4.v==v_4[j])].B_u, 
                          '.-', lw=0.8, label='u=%.2f,v=%.2f'%(u_4[i], v_4[j]))
            ax2[1,1].plot(df4[(df4.u==u_4[i])& (df4.v==v_4[j])].w, df4[(df4.u==u_4[i])& (df4.v==v_4[j])].B_v, 
                           '.-', lw=0.8, label='u=%.2f,v=%.2f'%(u_4[i], v_4[j]))
            ax2[1,2].plot(df4[(df4.u==u_4[i])& (df4.v==v_4[j])].w, df4[(df4.u==u_4[i])& (df4.v==v_4[j])].B_w, 
                           '.-', lw=0.8, label='u=%.2f,v=%.2f'%(u_4[i], v_4[j]))


for i in [0,1]:
    for j in [0,1,2]:
        ax2[i,j].legend(fontsize=3.5, loc='upper right')
        ax2[i,0].set_ylabel('$\mathsf{B_u}\,(G)$')
        ax2[i,1].set_ylabel('$\mathsf{B_v}\,(G)$')
        ax2[i,2].set_ylabel('$\mathsf{B_w}\,(G)$')
        ax2[i,j].set_xlabel('$\mathsf{w}\,(cm)$')
fig2.tight_layout(pad=1, h_pad=1,rect=[0,0,0.9,0.9])
fig2.savefig('plots_gradients/gradient_w')
# Out:
# <img src="data:image/png;base64,..." width="1100">
